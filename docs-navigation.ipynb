# %% [markdown]
# <div style="background: linear-gradient(135deg, #1976d2 0%, #1565c0 100%); color: white; border-radius: 16px; padding: 48px; text-align: center; margin: 32px 0; box-shadow: 0 8px 16px rgba(0,0,0,0.2);">
# <h1 style="font-size: 48px; font-weight: 800; margin: 0 0 16px 0; display: flex; align-items: center; justify-content: center; gap: 16px;">
# <span style="font-size: 56px;">🗺️</span>
# <span>EDS Documentation Navigator</span>
# </h1>
# <p style="font-size: 20px; margin: 16px 0; opacity: 0.95; font-weight: 300;">
# <strong style="font-weight: 600;">Lost in documentation?</strong> Not anymore! This interactive guide helps you navigate 23 comprehensive EDS documentation files like a pro.
# </p>
# </div>
#
# <div style="background: white; border-radius: 12px; padding: 32px; margin: 24px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1);">
# <h2 style="color: #1976d2; font-size: 28px; font-weight: 700; margin-bottom: 20px;">What is This?</h2>
# <p style="font-size: 18px; line-height: 1.8; color: #212121; margin-bottom: 16px;">
# The <code style="background: #f5f5f5; padding: 4px 8px; border-radius: 4px; font-family: 'Courier New', monospace; color: #dc004e;">docs/for-ai</code> directory contains detailed guides covering every aspect of Adobe Edge Delivery Services development. That's powerful... but overwhelming.
# </p>
# <p style="font-size: 20px; line-height: 1.8; color: #212121; font-weight: 500;">
# This notebook is your <strong style="color: #dc004e;">documentation GPS</strong> - it helps you find exactly what you need, fast.
# </p>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #fff3e0 0%, #ffe0b2 100%); border-radius: 12px; padding: 32px; margin: 24px 0; border-left: 6px solid #ed6c02;">
# <h3 style="color: #ed6c02; font-size: 24px; font-weight: 700; margin-bottom: 24px; display: flex; align-items: center; gap: 12px;">
# <span style="font-size: 28px;">📚</span>
# What You'll Learn
# </h3>
# <ul style="list-style: none; padding: 0; margin: 0;">
# <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 17px; display: flex; align-items: center; gap: 12px;">
# <span style="font-size: 24px;">📂</span>
# <span>Documentation structure (23 files, 4 categories)</span>
# </li>
# <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 17px; display: flex; align-items: center; gap: 12px;">
# <span style="font-size: 24px;">🔍</span>
# <span>How to find the right doc for your task</span>
# </li>
# <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 17px; display: flex; align-items: center; gap: 12px;">
# <span style="font-size: 24px;">🎓</span>
# <span>Role-based learning paths</span>
# </li>
# <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 17px; display: flex; align-items: center; gap: 12px;">
# <span style="font-size: 24px;">🔄</span>
# <span>Workflow-based navigation</span>
# </li>
# <li style="padding: 12px 0; font-size: 17px; display: flex; align-items: center; gap: 12px;">
# <span style="font-size: 24px;">💡</span>
# <span>Pro navigation strategies</span>
# </li>
# </ul>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 32px; margin: 24px 0; box-shadow: 0 4px 8px rgba(0,0,0,0.1); border-top: 4px solid #1976d2;">
# <h2 style="color: #1976d2; font-size: 28px; font-weight: 700; margin-bottom: 24px; display: flex; align-items: center; gap: 12px;">
# <span style="font-size: 32px;">📋</span>
# Table of Contents
# </h2>
#
# <nav aria-label="Presentation navigation">
#   <ul style="list-style: none; padding: 0; margin: 0;">
#     <li style="margin: 12px 0;">
#       <a href="#part-1-the-big-picture" style="color: #1976d2; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
#         <span style="font-size: 20px;">🌍</span>
#         Part 1: The Big Picture
#       </a>
#     </li>
#     <li style="margin: 12px 0;">
#       <a href="#part-2-by-your-role" style="color: #1976d2; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
#         <span style="font-size: 20px;">👥</span>
#         Part 2: By Your Role
#       </a>
#     </li>
#     <li style="margin: 12px 0;">
#       <a href="#part-3-by-your-task" style="color: #1976d2; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
#         <span style="font-size: 20px;">🎯</span>
#         Part 3: By Your Task
#       </a>
#     </li>
#     <li style="margin: 12px 0;">
#       <a href="#part-4-by-workflow" style="color: #1976d2; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
#         <span style="font-size: 20px;">🔄</span>
#         Part 4: By Workflow
#       </a>
#     </li>
#     <li style="margin: 12px 0;">
#       <a href="#part-5-document-categories" style="color: #1976d2; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
#         <span style="font-size: 20px;">📚</span>
#         Part 5: Document Categories
#       </a>
#     </li>
#     <li style="margin: 12px 0;">
#       <a href="#part-6-pro-navigator-tips" style="color: #1976d2; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
#         <span style="font-size: 20px;">💡</span>
#         Part 6: Pro Navigator Tips
#       </a>
#     </li>
#     <li style="margin: 12px 0;">
#       <a href="#resources-quick-reference" style="color: #1976d2; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
#         <span style="font-size: 20px;">📖</span>
#         Resources & Quick Reference
#       </a>
#     </li>
#   </ul>
# </nav>
# </div>

# %% [markdown]
# <section id="part-1-the-big-picture">
#
# ## 🌍 Part 1: The Big Picture
#
# ### The Documentation Ecosystem
#
# 23 documents organized into 4 categories:
#
# | Category | Count | Purpose |
# |----------|-------|----------|
# | Implementation | 7 | Build components |
# | Testing | 7 | Verify and fix |
# | Guidelines | 6 | Standards |
# | Reference | 3 | Deep dives |
#
# </section>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Two Entry Points</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **New to EDS?**
# 1. Start → [getting-started-guide.md](docs/for-ai/getting-started-guide.md)
# 2. Then → [eds.md](docs/for-ai/eds.md) (1,937 lines!)
#
# **Know what you're doing?**
# - Jump to specific guides
# - Use relationship mapping
# - Reference architecture standards
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Three Navigation Strategies</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# 1. **Role-based** - "I'm a new developer"
# 2. **Task-based** - "I need to build X"
# 3. **Workflow-based** - "I'm in testing phase"
# </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 24px; margin: 24px 0; border-left: 4px solid #0288d1;">
# ### Documentation Overview - Visual Structure
#
# **What this demonstrates:** Cards block showing organized documentation information.
#
# **Original code** (for reference - not executable in presentation mode):
# ```javascript
# // DOCUMENTATION OVERVIEW - Using cards to display structure
# const { showPreview } = await import('/scripts/ipynb-helpers.js');
#
# const structure = {
#   total: 23,
#   categories: {
#     implementation: 7,
#     testing: 7,
#     guidelines: 6,
#     reference: 3
#   }
# };
#
# console.log('📚 Total:', structure.total, 'documents');
# console.log('📂 Categories:', Object.keys(structure.categories).length);
# console.log('🚀 Entry points: getting-started + [eds.md](docs/for-ai/eds.md)');
#
# const content = '<div><div><strong>📚 Total Documents</strong></div><div>' + structure.total + ' comprehensive guides organized into 4 categories</div><div><strong>📂 Implementation</strong></div><div>' + structure.categories.implementation + ' guides for building components</div><div><strong>🧪 Testing</strong></div><div>' + structure.categories.testing + ' guides for verification</div><div><strong>📋 Guidelines</strong></div><div>' + structure.categories.guidelines + ' standards and requirements</div></div>';
#
# await showPreview('cards', content);
#
# return '✓ Well-organized documentation';
# ```
#
# **Purpose:** This code tested the cards block with documentation data and displayed it in an overlay preview.
#
# **Result in presentation:** The cards block below shows the same information in a beautiful, client-ready format.
#
# ---
#
#
# </div>
#
# <div class="cards block" role="group" aria-label="Documentation overview statistics">
#   <div>
#     <div>
#       <strong>📚 Total Documents</strong>
#     </div>
#     <div>
#       <p>23 comprehensive guides organized into 4 categories</p>
#     </div>
#   </div>
#   <div>
#     <div>
#       <strong>📂 Implementation</strong>
#     </div>
#     <div>
#       <p>7 guides for building components</p>
#     </div>
#   </div>
#   <div>
#     <div>
#       <strong>🧪 Testing</strong>
#     </div>
#     <div>
#       <p>7 guides for verification</p>
#     </div>
#   </div>
#   <div>
#     <div>
#       <strong>📋 Guidelines</strong>
#     </div>
#     <div>
#       <p>6 standards and requirements</p>
#     </div>
#   </div>
# </div>
#
# <script type="module">
#   const block = document.querySelector('.cards.block');
#   if (block) {
#     const module = await import('/blocks/cards/cards.js');
#     await module.default(block);
#   }
# </script>

# %% [markdown]
# <section id="part-2-by-your-role">
#
# ## 👥 Part 2: By Your Role
#
# ### 🌱 New Developer
#
# **Essential reading (in order):**
# 1. [getting-started-guide.md](docs/for-ai/getting-started-guide.md) - Orientation
# 2. [eds.md](docs/for-ai/eds.md) - Foundation (1,937 lines)
# 3. [implementation/raw-eds-blocks-guide.md](docs/for-ai/implementation/raw-eds-blocks-guide.md) - Simple components
# 4. [server-README.md](docs/for-ai/server-README.md) - Local dev setup
# 5. [guidelines/frontend-guidelines.md](docs/for-ai/guidelines/frontend-guidelines.md) - Coding standards
# 6. [explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md) - Create tutorials
#
# </section>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px; display: flex; align-items: center; gap: 12px;"><span style="font-size: 28px;">🚀</span>Experienced Developer</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Essential reading:**
# 1. [implementation/block-architecture-standards.md](docs/for-ai/implementation/block-architecture-standards.md)
# 2. [implementation/complex-eds-blocks-guide.md](docs/for-ai/implementation/complex-eds-blocks-guide.md)
# 3. [testing/eds-native-testing-standards.md](docs/for-ai/testing/eds-native-testing-standards.md)
# 4. [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md) - Interactive testing
# 5. [testing/debug.md](docs/for-ai/testing/debug.md) - Advanced debugging
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px; display: flex; align-items: center; gap: 12px;"><span style="font-size: 28px;">🏗️</span>Architect / Tech Lead</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Essential reading:**
# 1. [implementation/design-philosophy-guide.md](docs/for-ai/implementation/design-philosophy-guide.md)
# 2. [testing/eds-architecture-and-testing-guide.md](docs/for-ai/testing/eds-architecture-and-testing-guide.md)
# 3. [eds-webcomponents-review.md](docs/for-ai/eds-webcomponents-review.md)
# 4. [guidelines/backend-structure.md](docs/for-ai/guidelines/backend-structure.md)
# 5. [guidelines/security-checklist.md](docs/for-ai/guidelines/security-checklist.md)
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px; display: flex; align-items: center; gap: 12px;"><span style="font-size: 28px;">📊</span>Project Manager</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Essential reading:**
# 1. [guidelines/prd.md](docs/for-ai/guidelines/prd.md) - Requirements
# 2. [guidelines/app-flow.md](docs/for-ai/guidelines/app-flow.md) - Workflows
# 3. [guidelines/tech-stack.md](docs/for-ai/guidelines/tech-stack.md) - Technology
# 4. [guidelines/security-checklist.md](docs/for-ai/guidelines/security-checklist.md) - Security
# </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 24px; margin: 24px 0; border-left: 4px solid #0288d1;">
# ### Role-Based Documentation Guide
#
# **What this demonstrates:** Tabs block showing organized role-specific documentation paths.
#
# **Original code** (for reference - not executable in presentation mode):
# ```javascript
# // ROLE-BASED DOC FINDER - Using tabs for each role
# const { showPreview } = await import('/scripts/ipynb-helpers.js');
#
# function getDocsForRole(role) {
#   const docs = {
#     'new-dev': 6,
#     'experienced': 5,
#     'architect': 5,
#     'pm': 4
#   };
#   return docs[role];
# }
#
# console.log('New Developer:', getDocsForRole('new-dev'), 'docs');
# console.log('Experienced:', getDocsForRole('experienced'), 'docs');
# console.log('Architect:', getDocsForRole('architect'), 'docs');
# console.log('PM:', getDocsForRole('pm'), 'docs');
#
# const content = '<div><div>🌱 New Developer</div><div><strong>' + getDocsForRole('new-dev') + ' essential docs</strong><br>1. [getting-started-guide.md](docs/for-ai/getting-started-guide.md)<br>2. [eds.md](docs/for-ai/eds.md)<br>3. [raw-eds-blocks-guide.md](docs/for-ai/raw-eds-blocks-guide.md)<br>4. [server-README.md](docs/for-ai/server-README.md)<br>5. [frontend-guidelines.md](docs/for-ai/frontend-guidelines.md)<br>6. [explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)</div><div>🚀 Experienced</div><div><strong>' + getDocsForRole('experienced') + ' essential docs</strong><br>1. [block-architecture-standards.md](docs/for-ai/block-architecture-standards.md)<br>2. [complex-eds-blocks-guide.md](docs/for-ai/complex-eds-blocks-guide.md)<br>3. [eds-native-testing-standards.md](docs/for-ai/eds-native-testing-standards.md)<br>4. [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)<br>5. [debug.md](docs/for-ai/debug.md)</div><div>🏗️ Architect</div><div><strong>' + getDocsForRole('architect') + ' essential docs</strong><br>1. [design-philosophy-guide.md](docs/for-ai/design-philosophy-guide.md)<br>2. [eds-architecture-and-testing-guide.md](docs/for-ai/eds-architecture-and-testing-guide.md)<br>3. [eds-webcomponents-review.md](docs/for-ai/eds-webcomponents-review.md)<br>4. [backend-structure.md](docs/for-ai/backend-structure.md)<br>5. [security-checklist.md](docs/for-ai/security-checklist.md)</div><div>📊 PM</div><div><strong>' + getDocsForRole('pm') + ' essential docs</strong><br>1. [prd.md](docs/for-ai/prd.md)<br>2. [app-flow.md](docs/for-ai/app-flow.md)<br>3. [tech-stack.md](docs/for-ai/tech-stack.md)<br>4. [security-checklist.md](docs/for-ai/security-checklist.md)</div></div>';
#
# await showPreview('tabs', content);
#
# return '✓ Personalized reading lists';
# ```
#
# **Purpose:** This code tested the tabs block with documentation data and displayed it in an overlay preview.
#
# **Result in presentation:** The tabs block below shows the same information in a beautiful, client-ready format.
#
# ---
#
#
# </div>
#
# <div class="tabs block" role="tablist" aria-label="Role-based documentation paths">
#   <div>
#     <div role="tab" aria-selected="true">🌱 New Developer</div>
#     <div role="tabpanel">
#       <strong>6 essential docs</strong>
#       <ol>
#         <li>[getting-started-guide.md](docs/for-ai/getting-started-guide.md)</li>
#         <li>[eds.md](docs/for-ai/eds.md)</li>
#         <li>[raw-eds-blocks-guide.md](docs/for-ai/raw-eds-blocks-guide.md)</li>
#         <li>[server-README.md](docs/for-ai/server-README.md)</li>
#         <li>[frontend-guidelines.md](docs/for-ai/frontend-guidelines.md)</li>
#         <li>[explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)</li>
#       </ol>
#     </div>
#   </div>
#   <div>
#     <div role="tab" aria-selected="false">🚀 Experienced</div>
#     <div role="tabpanel">
#       <strong>5 essential docs</strong>
#       <ol>
#         <li>[block-architecture-standards.md](docs/for-ai/block-architecture-standards.md)</li>
#         <li>[complex-eds-blocks-guide.md](docs/for-ai/complex-eds-blocks-guide.md)</li>
#         <li>[eds-native-testing-standards.md](docs/for-ai/eds-native-testing-standards.md)</li>
#         <li>[explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)</li>
#         <li>[debug.md](docs/for-ai/debug.md)</li>
#       </ol>
#     </div>
#   </div>
#   <div>
#     <div role="tab" aria-selected="false">🏗️ Architect</div>
#     <div role="tabpanel">
#       <strong>5 essential docs</strong>
#       <ol>
#         <li>[design-philosophy-guide.md](docs/for-ai/design-philosophy-guide.md)</li>
#         <li>[eds-architecture-and-testing-guide.md](docs/for-ai/eds-architecture-and-testing-guide.md)</li>
#         <li>[eds-webcomponents-review.md](docs/for-ai/eds-webcomponents-review.md)</li>
#         <li>[backend-structure.md](docs/for-ai/backend-structure.md)</li>
#         <li>[security-checklist.md](docs/for-ai/security-checklist.md)</li>
#       </ol>
#     </div>
#   </div>
#   <div>
#     <div role="tab" aria-selected="false">📊 PM</div>
#     <div role="tabpanel">
#       <strong>4 essential docs</strong>
#       <ol>
#         <li>[prd.md](docs/for-ai/prd.md)</li>
#         <li>[app-flow.md](docs/for-ai/app-flow.md)</li>
#         <li>[tech-stack.md](docs/for-ai/tech-stack.md)</li>
#         <li>[security-checklist.md](docs/for-ai/security-checklist.md)</li>
#       </ol>
#     </div>
#   </div>
# </div>
#
# <script type="module">
#   const block = document.querySelector('.tabs.block');
#   if (block) {
#     const module = await import('/blocks/tabs/tabs.js');
#     await module.default(block);
#   }
# </script>

# %% [markdown]
# <section id="part-3-by-your-task">
#
# ## 🎯 Part 3: By Your Task
#
# ### Building Simple Component
#
# **Required:**
# - [implementation/raw-eds-blocks-guide.md](docs/for-ai/implementation/raw-eds-blocks-guide.md)
# - [implementation/block-architecture-standards.md](docs/for-ai/implementation/block-architecture-standards.md)
#
# **Helpful:**
# - [eds.md](docs/for-ai/eds.md) - Background
# - [testing/eds-native-testing-standards.md](docs/for-ai/testing/eds-native-testing-standards.md)
#
# </section>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Building Complex Component</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Required:**
# - [implementation/complex-eds-blocks-guide.md](docs/for-ai/implementation/complex-eds-blocks-guide.md)
# - [implementation/build-component-template.md](docs/for-ai/implementation/build-component-template.md)
# - [implementation/build-blocks-clarification.md](docs/for-ai/implementation/build-blocks-clarification.md)
#
# **Pro tip:** Check design philosophy first!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Testing Component</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Required:**
# - [testing/eds-native-testing-standards.md](docs/for-ai/testing/eds-native-testing-standards.md)
# - [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)
# - [testing/debug.md](docs/for-ai/testing/debug.md)
#
# **Advanced:**
# - [testing/instrumentation-how-it-works.md](docs/for-ai/testing/instrumentation-how-it-works.md)
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Debugging Issues</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Start here:**
# - [testing/debug.md](docs/for-ai/testing/debug.md) - Standard procedures
# - [testing/eds-architecture-and-testing-guide.md](docs/for-ai/testing/eds-architecture-and-testing-guide.md)
#
# **Performance issues:**
# - [testing/instrumentation-how-it-works.md](docs/for-ai/testing/instrumentation-how-it-works.md)
# - [eds.md](docs/for-ai/eds.md) (Core Web Vitals section)
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Creating Documentation</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Required:**
# - [explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)
# - Use `/create-notebook` command
#
# **Examples:**
# - This notebook!
# - `education.ipynb`
# </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 24px; margin: 24px 0; border-left: 4px solid #0288d1;">
# ### Task-Based Documentation Finder
#
# **What this demonstrates:** Accordion block showing task-specific documentation paths.
#
# **Original code** (for reference - not executable in presentation mode):
# ```javascript
# // TASK-BASED FINDER - Using accordion to show task categories
# const { showPreview } = await import('/scripts/ipynb-helpers.js');
#
# function getDocsForTask(task) {
#   const counts = {
#     'simple-component': 2,
#     'complex-component': 3,
#     'testing': 3,
#     'debugging': 2,
#     'documentation': 1
#   };
#   return counts[task];
# }
#
# const tasks = ['simple-component', 'testing', 'debugging'];
# tasks.forEach(task => {
#   console.log(task + ':', getDocsForTask(task), 'required docs');
# });
#
# const content = '<div><div>🔨 Building Simple Component</div><div><strong>' + getDocsForTask('simple-component') + ' required docs</strong><br>- [raw-eds-blocks-guide.md](docs/for-ai/raw-eds-blocks-guide.md)<br>- [block-architecture-standards.md](docs/for-ai/block-architecture-standards.md)</div><div>🏗️ Building Complex Component</div><div><strong>' + getDocsForTask('complex-component') + ' required docs</strong><br>- [complex-eds-blocks-guide.md](docs/for-ai/complex-eds-blocks-guide.md)<br>- [build-component-template.md](docs/for-ai/build-component-template.md)<br>- [build-blocks-clarification.md](docs/for-ai/build-blocks-clarification.md)</div><div>🧪 Testing Component</div><div><strong>' + getDocsForTask('testing') + ' required docs</strong><br>- [eds-native-testing-standards.md](docs/for-ai/eds-native-testing-standards.md)<br>- [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)<br>- [debug.md](docs/for-ai/debug.md)</div><div>🐛 Debugging Issues</div><div><strong>' + getDocsForTask('debugging') + ' required docs</strong><br>- [debug.md](docs/for-ai/debug.md)<br>- [eds-architecture-and-testing-guide.md](docs/for-ai/eds-architecture-and-testing-guide.md)</div><div>📝 Creating Documentation</div><div><strong>' + getDocsForTask('documentation') + ' required doc</strong><br>- [explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)<br>- Use /create-notebook command</div></div>';
#
# await showPreview('accordion', content);
#
# return '✓ Task-specific guidance';
# ```
#
# **Purpose:** This code tested the accordion block with documentation data and displayed it in an overlay preview.
#
# **Result in presentation:** The accordion block below shows the same information in a beautiful, client-ready format.
#
# ---
#
#
# </div>
#
# <div class="accordion block" role="region" aria-label="Task-based documentation finder">
#   <div>
#     <div>
#       <button type="button" aria-expanded="false" aria-controls="task-simple">
#         🔨 Building Simple Component
#       </button>
#     </div>
#     <div id="task-simple">
#       <strong>2 required docs</strong>
#       <ul>
#         <li>[raw-eds-blocks-guide.md](docs/for-ai/raw-eds-blocks-guide.md)</li>
#         <li>[block-architecture-standards.md](docs/for-ai/block-architecture-standards.md)</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div>
#       <button type="button" aria-expanded="false" aria-controls="task-complex">
#         🏗️ Building Complex Component
#       </button>
#     </div>
#     <div id="task-complex">
#       <strong>3 required docs</strong>
#       <ul>
#         <li>[complex-eds-blocks-guide.md](docs/for-ai/complex-eds-blocks-guide.md)</li>
#         <li>[build-component-template.md](docs/for-ai/build-component-template.md)</li>
#         <li>[build-blocks-clarification.md](docs/for-ai/build-blocks-clarification.md)</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div>
#       <button type="button" aria-expanded="false" aria-controls="task-testing">
#         🧪 Testing Component
#       </button>
#     </div>
#     <div id="task-testing">
#       <strong>3 required docs</strong>
#       <ul>
#         <li>[eds-native-testing-standards.md](docs/for-ai/eds-native-testing-standards.md)</li>
#         <li>[explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)</li>
#         <li>[debug.md](docs/for-ai/debug.md)</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div>
#       <button type="button" aria-expanded="false" aria-controls="task-debugging">
#         🐛 Debugging Issues
#       </button>
#     </div>
#     <div id="task-debugging">
#       <strong>2 required docs</strong>
#       <ul>
#         <li>[debug.md](docs/for-ai/debug.md)</li>
#         <li>[eds-architecture-and-testing-guide.md](docs/for-ai/eds-architecture-and-testing-guide.md)</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div>
#       <button type="button" aria-expanded="false" aria-controls="task-docs">
#         📝 Creating Documentation
#       </button>
#     </div>
#     <div id="task-docs">
#       <strong>1 required doc</strong>
#       <ul>
#         <li>[explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)</li>
#         <li>Use /create-notebook command</li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <script type="module">
#   const block = document.querySelector('.accordion.block');
#   if (block) {
#     const module = await import('/blocks/accordion/accordion.js');
#     await module.default(block);
#   }
# </script>

# %% [markdown]
# <section id="part-4-by-workflow">
#
# ## 🔄 Part 4: By Workflow
#
# ### Planning Phase
#
# **Read these:**
# 1. [guidelines/prd.md](docs/for-ai/guidelines/prd.md) - Requirements
# 2. [implementation/design-philosophy-guide.md](docs/for-ai/implementation/design-philosophy-guide.md) - Approach
# 3. [implementation/build-blocks-clarification.md](docs/for-ai/implementation/build-blocks-clarification.md) - Architecture
#
# **Answer:** What? Which approach? Timeline?
#
# </section>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Development Phase</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Start with:**
# 1. [implementation/block-architecture-standards.md](docs/for-ai/implementation/block-architecture-standards.md)
# 2. [implementation/raw-eds-blocks-guide.md](docs/for-ai/implementation/raw-eds-blocks-guide.md) OR
#    [implementation/complex-eds-blocks-guide.md](docs/for-ai/implementation/complex-eds-blocks-guide.md)
# 3. [server-README.md](docs/for-ai/server-README.md) - Local dev
# 4. [guidelines/frontend-guidelines.md](docs/for-ai/guidelines/frontend-guidelines.md) - Standards
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Testing Phase</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Essential:**
# 1. [testing/eds-native-testing-standards.md](docs/for-ai/testing/eds-native-testing-standards.md)
# 2. [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)
# 3. [testing/debug.md](docs/for-ai/testing/debug.md)
# 4. [testing/instrumentation-how-it-works.md](docs/for-ai/testing/instrumentation-how-it-works.md)
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Documentation Phase</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Use:**
# 1. [explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)
# 2. `/create-notebook` command
# 3. This notebook as example!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Deployment Phase</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Critical:**
# 1. [guidelines/backend-structure.md](docs/for-ai/guidelines/backend-structure.md)
# 2. [guidelines/security-checklist.md](docs/for-ai/guidelines/security-checklist.md)
# 3. [testing/investigation.md](docs/for-ai/testing/investigation.md)
# </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 24px; margin: 24px 0; border-left: 4px solid #0288d1;">
# ### Workflow Phase Navigator
#
# **What this demonstrates:** Grid block showing workflow phase documentation.
#
# **Original code** (for reference - not executable in presentation mode):
# ```javascript
# // WORKFLOW NAVIGATOR - Using grid to show phase breakdown
# const { showPreview } = await import('/scripts/ipynb-helpers.js');
#
# const phases = {
#   planning: 3,
#   development: 4,
#   testing: 4,
#   documentation: 1,
#   deployment: 3
# };
#
# console.log('📊 Docs per phase:');
# Object.entries(phases).forEach(([name, count]) => {
#   console.log('  ' + name + ':', count, 'docs');
# });
#
# const content = '<div><div><strong>📋 Planning</strong></div><div>' + phases.planning + ' docs<br>[prd.md](docs/for-ai/prd.md)<br>[design-philosophy-guide.md](docs/for-ai/design-philosophy-guide.md)<br>[build-blocks-clarification.md](docs/for-ai/build-blocks-clarification.md)</div><div><strong>💻 Development</strong></div><div>' + phases.development + ' docs<br>[block-architecture-standards.md](docs/for-ai/block-architecture-standards.md)<br>[raw/complex-eds-blocks-guide.md](docs/for-ai/raw/complex-eds-blocks-guide.md)<br>[server-README.md](docs/for-ai/server-README.md)<br>[frontend-guidelines.md](docs/for-ai/frontend-guidelines.md)</div><div><strong>🧪 Testing</strong></div><div>' + phases.testing + ' docs<br>[eds-native-testing-standards.md](docs/for-ai/eds-native-testing-standards.md)<br>[explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)<br>[debug.md](docs/for-ai/debug.md)<br>[instrumentation-how-it-works.md](docs/for-ai/instrumentation-how-it-works.md)</div><div><strong>📝 Documentation</strong></div><div>' + phases.documentation + ' doc<br>[explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)<br>/create-notebook command</div><div><strong>🚀 Deployment</strong></div><div>' + phases.deployment + ' docs<br>[backend-structure.md](docs/for-ai/backend-structure.md)<br>[security-checklist.md](docs/for-ai/security-checklist.md)<br>[investigation.md](docs/for-ai/investigation.md)</div></div>';
#
# await showPreview('grid', content);
#
# return '✓ Workflow-based navigation';
# ```
#
# **Purpose:** This code tested the grid block with documentation data and displayed it in an overlay preview.
#
# **Result in presentation:** The grid block below shows the same information in a beautiful, client-ready format.
#
# ---
#
#
# </div>
#
# <div class="grid block" role="grid" aria-label="Workflow phase documentation breakdown">
#   <div>
#     <div><strong>📋 Planning</strong></div>
#     <div>
#       <p><strong>3 docs</strong></p>
#       <ul>
#         <li>[prd.md](docs/for-ai/prd.md)</li>
#         <li>[design-philosophy-guide.md](docs/for-ai/design-philosophy-guide.md)</li>
#         <li>[build-blocks-clarification.md](docs/for-ai/build-blocks-clarification.md)</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div><strong>💻 Development</strong></div>
#     <div>
#       <p><strong>4 docs</strong></p>
#       <ul>
#         <li>[block-architecture-standards.md](docs/for-ai/block-architecture-standards.md)</li>
#         <li>[raw/complex-eds-blocks-guide.md](docs/for-ai/raw/complex-eds-blocks-guide.md)</li>
#         <li>[server-README.md](docs/for-ai/server-README.md)</li>
#         <li>[frontend-guidelines.md](docs/for-ai/frontend-guidelines.md)</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div><strong>🧪 Testing</strong></div>
#     <div>
#       <p><strong>4 docs</strong></p>
#       <ul>
#         <li>[eds-native-testing-standards.md](docs/for-ai/eds-native-testing-standards.md)</li>
#         <li>[explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)</li>
#         <li>[debug.md](docs/for-ai/debug.md)</li>
#         <li>[instrumentation-how-it-works.md](docs/for-ai/instrumentation-how-it-works.md)</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div><strong>📝 Documentation</strong></div>
#     <div>
#       <p><strong>1 doc</strong></p>
#       <ul>
#         <li>[explaining-educational-notebooks.md](docs/for-ai/explaining-educational-notebooks.md)</li>
#         <li>/create-notebook command</li>
#       </ul>
#     </div>
#   </div>
#   <div>
#     <div><strong>🚀 Deployment</strong></div>
#     <div>
#       <p><strong>3 docs</strong></p>
#       <ul>
#         <li>[backend-structure.md](docs/for-ai/backend-structure.md)</li>
#         <li>[security-checklist.md](docs/for-ai/security-checklist.md)</li>
#         <li>[investigation.md](docs/for-ai/investigation.md)</li>
#       </ul>
#     </div>
#   </div>
# </div>
#
# <script type="module">
#   const block = document.querySelector('.grid.block');
#   if (block) {
#     const module = await import('/blocks/grid/grid.js');
#     await module.default(block);
#   }
# </script>

# %% [markdown]
# <section id="part-5-document-categories">
#
# ## 📚 Part 5: Document Categories
#
# ### Implementation Guides (7 docs)
#
# **Purpose:** How to build components
#
# **Key docs:**
# - [raw-eds-blocks-guide.md](docs/for-ai/raw-eds-blocks-guide.md) - Simple
# - [complex-eds-blocks-guide.md](docs/for-ai/complex-eds-blocks-guide.md) - Advanced
# - [block-architecture-standards.md](docs/for-ai/block-architecture-standards.md) - Standards
# - [design-philosophy-guide.md](docs/for-ai/design-philosophy-guide.md) - Decisions
#
# </section>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Testing & Debugging (7 docs)</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Purpose:** Verify, fix, optimize
#
# **Key docs:**
# - [eds-native-testing-standards.md](docs/for-ai/eds-native-testing-standards.md) - Framework
# - [debug.md](docs/for-ai/debug.md) - Procedures
# - [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md) - Interactive
# - [instrumentation-how-it-works.md](docs/for-ai/instrumentation-how-it-works.md) - Performance
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Project Guidelines (6 docs)</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Purpose:** Standards and requirements
#
# **Key docs:**
# - [prd.md](docs/for-ai/prd.md) - Requirements
# - [frontend-guidelines.md](docs/for-ai/frontend-guidelines.md) - Standards
# - [security-checklist.md](docs/for-ai/security-checklist.md) - Security
# - [tech-stack.md](docs/for-ai/tech-stack.md) - Technology
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Reference Materials (3 docs)</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Purpose:** Deep analysis
#
# **Key docs:**
# - [eds.md](docs/for-ai/eds.md) - Comprehensive (1,937 lines!)
# - [eds-appendix.md](docs/for-ai/eds-appendix.md) - Supplementary
# - [eds-webcomponents-review.md](docs/for-ai/eds-webcomponents-review.md) - Architecture
# </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 24px; margin: 24px 0; border-left: 4px solid #0288d1;">
# ### Category Breakdown Summary
#
# **What this demonstrates:** Table block showing documentation categories with striped variation for better readability.
#
# **Original code** (for reference - not executable in presentation mode):
# ```javascript
# // CATEGORY BREAKDOWN - Using table to organize categories
# const { showPreview } = await import('/scripts/ipynb-helpers.js');
#
# const categories = {
#   implementation: { docs: 7, focus: 'Building' },
#   testing: { docs: 7, focus: 'Verifying' },
#   guidelines: { docs: 6, focus: 'Standards' },
#   reference: { docs: 3, focus: 'Deep dives' }
# };
#
# console.log('📂 Categories:');
# Object.entries(categories).forEach(([name, info]) => {
#   console.log('  ' + name + ':', info.docs, 'docs (' + info.focus + ')');
# });
#
# const content = '<div><div>Category</div><div>Count</div><div>Focus</div><div>Implementation</div><div>7</div><div>Building components</div><div>Testing</div><div>7</div><div>Verifying functionality</div><div>Guidelines</div><div>6</div><div>Standards &amp; requirements</div><div>Reference</div><div>3</div><div>Deep analysis</div></div>';
#
# await showPreview('table', content);
#
# return '✓ 4 categories, 23 total docs';
# ```
#
# **Purpose:** This code tested the table block with documentation data and displayed it in an overlay preview.
#
# **Result in presentation:** The table block below shows the same information in a beautiful, client-ready format.
#
# ---
#
#
# </div>
#
# <div class="table striped block" role="table" aria-label="Documentation category summary">
#   <div role="row">
#     <div role="columnheader"><strong>Category</strong></div>
#     <div role="columnheader"><strong>Count</strong></div>
#     <div role="columnheader"><strong>Focus</strong></div>
#   </div>
#   <div role="row">
#     <div role="cell">Implementation</div>
#     <div role="cell">7</div>
#     <div role="cell">Building components</div>
#   </div>
#   <div role="row">
#     <div role="cell">Testing</div>
#     <div role="cell">7</div>
#     <div role="cell">Verifying functionality</div>
#   </div>
#   <div role="row">
#     <div role="cell">Guidelines</div>
#     <div role="cell">6</div>
#     <div role="cell">Standards & requirements</div>
#   </div>
#   <div role="row">
#     <div role="cell">Reference</div>
#     <div role="cell">3</div>
#     <div role="cell">Deep analysis</div>
#   </div>
# </div>
#
# <script type="module">
#   const block = document.querySelector('.table.block');
#   if (block) {
#     const module = await import('/blocks/table/table.js');
#     await module.default(block);
#   }
# </script>

# %% [markdown]
# <section id="part-6-pro-navigator-tips">
#
# ## 💡 Part 6: Pro Navigator Tips
#
# ### Tip 1: Use Relationship Mapping
#
# **Document:** [document-relationship-mapping.md](docs/for-ai/document-relationship-mapping.md)
#
# Shows how all docs connect:
# - Cross-references
# - Navigation flows
# - User journeys
#
# </section>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Tip 2: Start with Getting Started</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Document:** [getting-started-guide.md](docs/for-ai/getting-started-guide.md)
#
# Your GPS calibration:
# - Role-based paths
# - Quick reference
# - Scenario solutions
#
# Even experts benefit from this!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Tip 3: [eds.md](docs/for-ai/eds.md) is Your Bible</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Document:** [eds.md](docs/for-ai/eds.md) (1,937 lines)
#
# Comprehensive reference:
# - Document transformation
# - Content processing
# - Block development
# - Performance optimization
#
# **Don't read cover-to-cover** - use as reference!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Tip 4: Know the Dual-Pattern</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# | Approach | When | Doc |
# |----------|------|-----|
# | EDS-Native | Simple | raw-eds-blocks |
# | Build-Enhanced | Complex | complex-eds-blocks |
#
# **Decision guide:** [design-philosophy-guide.md](docs/for-ai/design-philosophy-guide.md)
#
# Most projects need BOTH!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Tip 5: Interactive Testing</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Document:** [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)
#
# Jupyter notebooks provide:
# - Context-aware testing
# - Live previews
# - Interactive debugging
#
# Game changer for development!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Tip 6: Build Personal Quick Reference</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Example:**
# ```markdown
# My Frequent Docs:
# - Complex: [complex-eds-blocks-guide.md](docs/for-ai/complex-eds-blocks-guide.md)
# - Testing: [explaining-jupyter.md](docs/for-ai/explaining-jupyter.md)
# - Debug: [debug.md](docs/for-ai/debug.md)
# ```
#
# Different for each role and phase!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Tip 7: Use Slash Commands</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Available:**
# - `/new-block` - Create block
# - `/test-block` - Run tests
# - `/create-notebook` - Create tutorial
# - `/lint-all` - Run linting
# - `/check-block` - Review
#
# Commands follow best practices automatically!
# </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 24px; margin: 24px 0; border-left: 4px solid #0288d1;">
# ### Pro Navigator Tips - High Impact
#
# **What this demonstrates:** Cards block highlighting high-impact navigation strategies.
#
# **Original code** (for reference - not executable in presentation mode):
# ```javascript
# // PRO TIPS SUMMARY - Using cards to highlight impact
# const { showPreview } = await import('/scripts/ipynb-helpers.js');
#
# const tips = [
#   { tip: 'Use relationship mapping', impact: 'High' },
#   { tip: 'Start with getting-started', impact: 'High' },
#   { tip: 'Reference [eds.md](docs/for-ai/eds.md)', impact: 'High' },
#   { tip: 'Know dual-pattern', impact: 'High' },
#   { tip: 'Use interactive testing', impact: 'Medium' },
#   { tip: 'Build quick reference', impact: 'Medium' },
#   { tip: 'Leverage commands', impact: 'High' }
# ];
#
# const highImpact = tips.filter(t => t.impact === 'High');
# console.log('🎯 High-Impact Tips:', highImpact.length);
# highImpact.forEach(t => console.log('  - ' + t.tip));
#
# const content = '<div><div><strong>🎯 Use Relationship Mapping</strong></div><div>Impact: High<br>Shows how all docs connect with cross-references and flows</div><div><strong>🚀 Start with Getting Started</strong></div><div>Impact: High<br>Your navigation calibration guide for all roles</div><div><strong>📖 Reference [eds.md](docs/for-ai/eds.md)</strong></div><div>Impact: High<br>1,937 lines of comprehensive reference material</div><div><strong>🔄 Know Dual-Pattern</strong></div><div>Impact: High<br>EDS-Native vs Build-Enhanced approaches</div><div><strong>⚡ Leverage Commands</strong></div><div>Impact: High<br>/new-block, /test-block, /create-notebook</div></div>';
#
# await showPreview('cards', content);
#
# return '✓ Navigation mastery';
# ```
#
# **Purpose:** This code tested the cards block with documentation data and displayed it in an overlay preview.
#
# **Result in presentation:** The cards block below shows the same information in a beautiful, client-ready format.
#
# ---
#
#
# </div>
#
# <div class="cards block" role="group" aria-label="High-impact navigation tips">
#   <div>
#     <div>
#       <strong>🎯 Use Relationship Mapping</strong>
#     </div>
#     <div>
#       <p><strong>Impact: High</strong></p>
#       <p>Shows how all docs connect with cross-references and flows</p>
#     </div>
#   </div>
#   <div>
#     <div>
#       <strong>🚀 Start with Getting Started</strong>
#     </div>
#     <div>
#       <p><strong>Impact: High</strong></p>
#       <p>Your navigation calibration guide for all roles</p>
#     </div>
#   </div>
#   <div>
#     <div>
#       <strong>📖 Reference [eds.md](docs/for-ai/eds.md)</strong>
#     </div>
#     <div>
#       <p><strong>Impact: High</strong></p>
#       <p>1,937 lines of comprehensive reference material</p>
#     </div>
#   </div>
#   <div>
#     <div>
#       <strong>🔄 Know Dual-Pattern</strong>
#     </div>
#     <div>
#       <p><strong>Impact: High</strong></p>
#       <p>EDS-Native vs Build-Enhanced approaches</p>
#     </div>
#   </div>
#   <div>
#     <div>
#       <strong>⚡ Leverage Commands</strong>
#     </div>
#     <div>
#       <p><strong>Impact: High</strong></p>
#       <p>/new-block, /test-block, /create-notebook</p>
#     </div>
#   </div>
# </div>
#
# <script type="module">
#   const block = document.querySelector('.cards.block');
#   if (block) {
#     const module = await import('/blocks/cards/cards.js');
#     await module.default(block);
#   }
# </script>

# %% [markdown]
# <section id="resources-quick-reference">
#
# ## 📚 Resources & Quick Reference
#
# ### What You've Learned
#
# ✅ Documentation structure (23 files, 4 categories)
# ✅ Role-based navigation
# ✅ Task-based navigation
# ✅ Workflow-based navigation
# ✅ Pro strategies
#
# </section>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Quick Decision Tree</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# ```
# New to EDS?
#   ↓ Yes → getting-started → [eds.md](docs/for-ai/eds.md)
#   ↓ No → Know your task?
#     ↓ Yes → Part 3 (task-based)
#     ↓ No → Part 4 (workflow-based)
# ```
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Essential Bookmarks</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# **Always useful:**
# - [getting-started-guide.md](docs/for-ai/getting-started-guide.md)
# - [document-relationship-mapping.md](docs/for-ai/document-relationship-mapping.md)
# - [eds.md](docs/for-ai/eds.md)
#
# **For building:**
# - [block-architecture-standards.md](docs/for-ai/block-architecture-standards.md)
# - [raw-eds-blocks-guide.md](docs/for-ai/raw-eds-blocks-guide.md) OR
#   [complex-eds-blocks-guide.md](docs/for-ai/complex-eds-blocks-guide.md)
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Statistics</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# | Metric | Value |
# |--------|-------|
# | Total docs | 23 |
# | Implementation | 7 |
# | Testing | 7 |
# | Guidelines | 6 |
# | Reference | 3 |
# | Longest | [eds.md](docs/for-ai/eds.md) (1,937 lines) |
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Your Next Steps</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# 1. **Find your role's list** (Part 2)
# 2. **Try interactive testing** ([explaining-jupyter.md](docs/for-ai/explaining-jupyter.md))
# 3. **Build something** (use relevant guide)
# 4. **Create tutorial** (`/create-notebook`)
#
# Use this navigator when stuck!
# </div>
# </div>

# %% [markdown]
# <div style="background: white; border-radius: 12px; padding: 28px; margin: 20px 0; box-shadow: 0 2px 8px rgba(0,0,0,0.08);">
# <h3 style="color: #1976d2; font-size: 24px; font-weight: 700; margin-bottom: 20px;">Remember</h3>
# <div style="color: #212121; line-height: 1.8; font-size: 16px;">
#
# You don't need to read everything.
#
# You need to know:
# 1. ✅ Where things are
# 2. ✅ How to find them
# 3. ✅ When to use them
#
# **Now go build something!** 🚀
# </div>
# </div>

# %% [markdown]
# <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 24px; margin: 24px 0; border-left: 4px solid #0288d1;">
# ### Navigation Complete!
#
# **What this demonstrates:** Hero block with completion message and call-to-action.
#
# **Original code** (for reference - not executable in presentation mode):
# ```javascript
# // FINAL SUMMARY - Using hero block for completion message
# const { showPreview } = await import('/scripts/ipynb-helpers.js');
#
# console.log('🗺️ EDS Documentation Navigator');
# console.log('');
# console.log('📊 Coverage:');
# console.log('  Total: 23 docs');
# console.log('  Categories: 4');
# console.log('  Approaches: 3');
# console.log('');
# console.log('✅ You learned:');
# console.log('  - Navigate by role');
# console.log('  - Navigate by task');
# console.log('  - Navigate by workflow');
# console.log('');
# console.log('🚀 Ready to navigate!');
#
# const content = '<div><div>🗺️ Navigation Complete!</div><div>You now have the skills to find any documentation you need across 23 files and 4 categories. Navigate by role, task, or workflow—choose your path and start building!</div></div>';
#
# await showPreview('hero', content);
#
# return '🎉 Navigator complete!';
# ```
#
# **Purpose:** This code tested the hero block with documentation data and displayed it in an overlay preview.
#
# **Result in presentation:** The hero block below shows the same information in a beautiful, client-ready format.
#
# ---
#
#
# </div>
#
# <div class="hero block" role="banner" aria-label="Presentation completion">
#   <div>
#     <div>
#       <h1>🗺️ Navigation Complete!</h1>
#       <p>You now have the skills to find any documentation you need across 23 files and 4 categories. Navigate by role, task, or workflow—choose your path and start building!</p>
#     </div>
#   </div>
# </div>
#
# <script type="module">
#   const block = document.querySelector('.hero.block');
#   if (block) {
#     const module = await import('/blocks/hero/hero.js');
#     await module.default(block);
#   }
# </script>
