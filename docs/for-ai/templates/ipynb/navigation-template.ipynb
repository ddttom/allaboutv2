// %% [markdown]
// # 🗺️ [Your Documentation Title]
//
// [Brief hook sentence describing what this navigation guide helps with]
//
// <!-- action-cards -->
//
// - [Quick Start](#)
// - [Navigation Strategies](#)
// - [Pro Tips](#)

// %% [markdown]
// ### 📋 Complete Guide Overview
//
// **Reading time: [X-Y] minutes** | **[N] cells** | **[N] parts**
//
// This guide offers multiple ways to navigate:
//
// | Part | Focus | Cells | Time |
// |------|-------|-------|------|
// | 1. [Overview](#cell-1) | Why & What | X | X min |
// | 2. [By Role](#cell-2) | Role-based paths | X | X min |
// | 3. [By Task](#cell-3) | Task-based guides | X | X min |
// | 4. [By Workflow](#cell-4) | Process phases | X | X min |
// | 5. [Categories](#cell-5) | Browse all | X | X min |
// | 6. [Pro Tips](#cell-6) | Expert strategies | X | X min |
//
// **Quick access:**
// - 🚨 [Emergency Help](#cell-emergency) - Need help NOW?
// - 🌟 [Essential Docs](#cell-essential) - The must-reads
// - 🔍 [Search Guide](#cell-search) - Find what you need

// %% [markdown]
// ### 🚨 Emergency Navigation - I Need Help NOW!
//
// **Skip the learning - jump straight to solutions:**
//
// | Problem | Immediate Solution |
// |---------|-------------------|
// | 🔴 **[Problem 1]** | → [solution-doc.md](path/to/doc.md) - Description |
// | 🔴 **[Problem 2]** | → [solution-doc.md](path/to/doc.md) - Description |
// | 🔴 **[Problem 3]** | → [solution-doc.md](path/to/doc.md) - Description |
// | 🔴 **[Problem 4]** | → [solution-doc.md](path/to/doc.md) - Description |
//
// **For everything else:** Use the navigation below based on your role, task, or workflow phase.

// %% [markdown]
// ### 🌟 The Essential [Number] - Bookmark These Now
//
// Every [user/role] should have these docs open:
//
// | Doc | Purpose | When to Use |
// |-----|---------|-------------|
// | **[index.md](path/index.md)** | Your home base | Starting point |
// | **[core-doc.md](path/core.md)** | Your reference bible | Deep questions |
// | **[flows.md](path/flows.md)** | Your decision trees | "Should I use X or Y?" |
//
// **Pro tip:** Keep these in browser tabs while working.

// %% [markdown]
// ### 🔍 How to Search Within Documentation
//
// **Looking for [topic 1]?**
// Keywords: `keyword1`, `keyword2`, `keyword3`
//
// **Need [topic 2] info?**
// Keywords: `keyword4`, `keyword5`, `keyword6`
//
// **Stuck with [topic 3]?**
// Keywords: `keyword7`, `keyword8`, `keyword9`
//
// **Pro tip:** Use your IDE's global search (Cmd/Ctrl+Shift+F) across docs directory.

// %% [markdown]
// ### 📖 Icon Guide
//
// **Navigation & Structure:**
// - 📂 = Structure/Organization
// - 🗺️ = Navigation/Maps
// - 📋 = Lists/Checklists
//
// **Learning & Information:**
// - 🎓 = Learning paths
// - 📚 = Documentation
// - 💡 = Tips & Tricks
//
// **Status & Actions:**
// - ✅ = Recommended/Best practices
// - ❌ = Avoid/Don't do
// - ⚠️ = Warning/Caution
// - 🚨 = Emergency/Urgent

// %% [markdown]
// ## 📍 What is This?
//
// [Explain what documentation system you're navigating]
//
// This notebook is your **documentation GPS** - it helps you find exactly what you need, fast.

// %% [markdown]
// ## ⚠️ Why Navigation Matters
//
// **The Documentation Crisis**
//
// [Explain the specific documentation challenges your system solves]
//
// **Living documentation solves this** through:
// - Executable examples that can't lie
// - Self-verification on every use
// - Multi-audience design serving everyone
//
// This navigator embodies those principles.

// %% [markdown]
// ### 📚 What You'll Learn
//
// - 📂 Documentation structure and organization
// - 🔍 How to find the right doc for your task
// - 🎓 Role-based learning paths
// - 🔄 Workflow-based navigation
// - 💡 Pro navigation strategies

// %% [markdown]
// ### 🌍 Part 1: The Big Picture
// **Progress: 1 of [N]** 🔵⚪⚪⚪⚪⚪
// **Reading time: X minutes**
//
// **The Documentation Ecosystem**
//
// [Overview of your documentation structure]
//
// | Category | Purpose |
// |----------|----------|
// | [Category 1] | [Description] |
// | [Category 2] | [Description] |
// | [Category 3] | [Description] |

// %% [markdown]
// ### ✨ Living Documentation Principles
//
// This documentation system follows three core principles:
//
// **1. Executable Truth**
// - [Examples specific to your system]
//
// **2. Self-Verification**
// - [Examples specific to your system]
//
// **3. Multi-Audience & Multi-Modal**
// - [Examples specific to your system]

// %% [markdown]
// ### ✅ Part 1 Complete: The Big Picture
//
// **What you've learned:**
// - 📂 [Key point 1]
// - ✨ [Key point 2]
// - 🎯 [Key point 3]
//
// **Next steps:**
// - 👤 [Navigate by your role →](#cell-role-1) - Find your learning path
// - 🎯 [Navigate by your task →](#cell-task-1) - Jump to specific goal
// - 🔄 [Navigate by workflow →](#cell-workflow-1) - Follow your phase

// %% [markdown]
// Now that you understand the structure, let's explore navigation based on YOUR role...
//
// <!-- action-cards -->
//
// - [Role 1](#)
// - [Role 2](#)
// - [Role 3](#)
// - [Role 4](#)

// %% [markdown]
// ### 👥 Part 2: By Your Role - [Role Name]
// **Progress: 2 of [N]** 🔵🔵⚪⚪⚪⚪
// **Reading time: X minutes**
//
// **Required (in order):**
// 1. [doc1.md](path/doc1.md) - Description
// 2. [doc2.md](path/doc2.md) - Description
//
// **Recommended:**
// - [doc3.md](path/doc3.md) - Description
//
// **Optional (Advanced):**
// - [doc4.md](path/doc4.md) - Description

// %% [markdown]
// ### ✅ Part 2 Complete: Role-Based Navigation
//
// **What you've learned:**
// - 👥 [N] distinct role-based learning paths
// - 📚 Essential docs for each role
// - 🎓 Reading order recommendations
//
// **Your role clear?**
// ✓ Great! Bookmark your essential docs and dive in.
//
// **Still exploring?**
// - 🎯 [Try task-based navigation →](#cell-task-1) - "I need to do X"
// - 🔄 [Try workflow-based →](#cell-workflow-1) - "I'm in X phase"
//
// [↑ Back to Top](#cell-0-hero)

// %% [markdown]
// Individual roles are important, but tasks show you what to do...
//
// <!-- action-cards -->
//
// - [Task 1](#)
// - [Task 2](#)
// - [Task 3](#)
// - [Task 4](#)

// %% [markdown]
// ### 🎯 Part 3: By Your Task - [Task Name]
// **Progress: 3 of [N]** 🔵🔵🔵⚪⚪⚪
// **Reading time: X minutes**
//
// **Required:**
// - [doc1.md](path/doc1.md) - Description
// - [doc2.md](path/doc2.md) - Description
//
// **Recommended:**
// - [doc3.md](path/doc3.md) - Description
//
// **Pro tip:** [Helpful advice for this task]

// %% [markdown]
// ### ✅ Part 3 Complete: Task-Based Navigation
//
// **What you've learned:**
// - 🎯 [N] common task categories
// - 📖 Required docs for each task
// - 💡 Pro tips for complex tasks
//
// **Found what you need?**
// ✓ Perfect! Head to those docs and start building.
//
// **Want the big picture?**
// - 🔄 [See full workflows →](#cell-workflow-1) - Full process
// - 💡 [Get pro strategies →](#cell-tips-1) - Expert tips
//
// [↑ Back to Top](#cell-0-hero)

// %% [markdown]
// Individual tasks are important, but workflows show you the complete journey...
//
// <!-- action-cards -->
//
// - [Phase 1](#)
// - [Phase 2](#)
// - [Phase 3](#)
// - [Phase 4](#)

// %% [markdown]
// ### 🔄 Part 4: By Workflow - [Phase Name]
// **Progress: 4 of [N]** 🔵🔵🔵🔵⚪⚪
// **Reading time: X minutes**
//
// **Read these:**
// 1. [doc1.md](path/doc1.md) - Description
// 2. [doc2.md](path/doc2.md) - Description
// 3. [doc3.md](path/doc3.md) - Description
//
// **Answer:** [What questions this phase addresses]

// %% [markdown]
// ### ✅ Part 4 Complete: Workflow-Based Navigation
//
// **What you've learned:**
// - 🔄 [N] development phases
// - 📚 Essential docs for each phase
// - 🎯 Phase-specific focus areas
//
// **Clear on your phase?**
// ✓ Excellent! Follow those docs through your workflow.
//
// **Want more context?**
// - 📂 [Browse all categories →](#cell-category-1) - Systematic overview
// - 💡 [Master pro tips →](#cell-tips-1) - Navigation strategies
//
// [↑ Back to Top](#cell-0-hero)

// %% [markdown]
// Understanding workflows helps with the big picture. Sometimes you just need to browse by category...
//
// <!-- action-cards -->
//
// - [Category 1](#)
// - [Category 2](#)
// - [Category 3](#)
// - [Category 4](#)

// %% [markdown]
// ### 📚 Part 5: Document Categories - [Category Name]
// **Progress: 5 of [N]** 🔵🔵🔵🔵🔵⚪
// **Reading time: X minutes**
//
// **Purpose:** [What this category covers]
//
// **All docs:**
// - [doc1.md](path/doc1.md) - Description
// - [doc2.md](path/doc2.md) - Description
// - [doc3.md](path/doc3.md) - Description

// %% [markdown]
// ### ✅ Part 5 Complete: Document Categories
//
// **What you've learned:**
// - 📂 All [N] documentation categories
// - 📊 Complete catalog systematically organized
// - 🗺️ Category purposes and contents
//
// **Found your docs?**
// ✓ Great! You now know the full landscape.
//
// **Want expert guidance?**
// - 💡 [Learn pro strategies →](#cell-tips-1) - Navigation tips
// - 🌍 [See universal patterns →](#cell-universal) - Apply beyond this project
//
// [↑ Back to Top](#cell-0-hero)

// %% [markdown]
// You've learned the structure. Now master the expert strategies...
//
// <!-- action-cards -->
//
// - [Tip 1](#)
// - [Tip 2](#)
// - [Tip 3](#)

// %% [markdown]
// ### 💡 Part 6: Pro Navigator Tips - Tip 1: [Tip Name]
// **Progress: 6 of [N]** 🔵🔵🔵🔵🔵🔵
// **Reading time: X minutes**
//
// **[Tip Title]**
//
// [Tip content with examples and guidance]

// %% [markdown]
// ### ✅ Part 6 Complete: Pro Navigator Tips
//
// **What you've mastered:**
// - 🗺️ [Key strategy 1]
// - 📖 [Key strategy 2]
// - 🔄 [Key strategy 3]
//
// **You're now a documentation power user!**
//
// **What's next?**
// - 🌍 [Universal patterns →](#cell-universal) - Apply these strategies anywhere
// - 📚 [Final thoughts →](#cell-remember) - Remember what matters
//
// [↑ Back to Top](#cell-0-hero)

// %% [markdown]
// ## 🌍 Part 7: Universal Patterns - Beyond This Project
//
// The navigation strategies in this system apply to ANY project:
//
// **[Example System 1]**
// - Role-based: [roles]
// - Task-based: [tasks]
// - Workflow-based: [phases]
// - Living docs: [executable examples]
//
// **[Example System 2]**
// - Role-based: [roles]
// - Task-based: [tasks]
// - Workflow-based: [phases]
// - Living docs: [executable examples]
//
// **Key insight:** These patterns aren't project-specific - they're universal documentation architecture.

// %% [markdown]
// ### ⚠️ Troubleshooting Navigation Issues
//
// **Issue:** "I don't fit cleanly into any of these roles"
// **Solution:** [Your solution]
//
// **Issue:** "This doc references another doc I can't find"
// **Solution:** [Your solution]
//
// **Issue:** "The documentation seems outdated"
// **Solution:** [Your solution]
//
// **Issue:** "There are too many docs - I'm overwhelmed"
// **Solution:** [Your solution]
//
// **Still stuck?** → [getting-started.md](path/getting-started.md)

// %% [markdown]
// ### 💭 Remember - This IS Living Documentation
//
// **You don't need to read everything.**
//
// You need to know:
// 1. ✅ Where things are (organized by category)
// 2. ✅ How to find them (decision trees + cross-references)
// 3. ✅ When to use them (role + task + workflow navigation)
//
// **Meta-Insight:** This notebook demonstrates the very principles it teaches:
//
// - **Executable** - Open it in notebook mode
// - **Multi-audience** - Serves all roles
// - **Multi-modal navigation** - Browse by role, task, or workflow
// - **Progressive disclosure** - Summaries → details → deep dives
// - **Self-documenting** - Shows the pattern by being the pattern
//
// This isn't just a navigation guide - it's a working example of living documentation architecture.
//
// **Now go build something!** 🚀
