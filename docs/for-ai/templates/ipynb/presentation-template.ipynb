// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h1 style="color: #0d47a1; font-size: 48px; font-weight: 800; margin-bottom: 24px; text-align: center;">🎯 Your Presentation Title</h1>
//
// <p style="text-align: center; font-size: 20px; margin: 0;">Your compelling subtitle or tagline goes here</p>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">✨ What You'll Learn</h2>
//
// <p>Brief introduction to what this presentation covers.</p>
//
// <ul style="line-height: 1.8;">
//   <li>Key point 1</li>
//   <li>Key point 2</li>
//   <li>Key point 3</li>
// </ul>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">📋 Table of Contents</h2>
//
// <ul style="line-height: 1.8; list-style: none; padding: 0;">
//   <li style="margin: 12px 0;"><a href="#section-1" style="color: #0288d1; text-decoration: none; font-size: 18px; font-weight: 500;">📌 Section 1: Introduction</a></li>
//   <li style="margin: 12px 0;"><a href="#section-2" style="color: #0288d1; text-decoration: none; font-size: 18px; font-weight: 500;">🚀 Section 2: Main Content</a></li>
//   <li style="margin: 12px 0;"><a href="#section-3" style="color: #0288d1; text-decoration: none; font-size: 18px; font-weight: 500;">💡 Section 3: Key Insights</a></li>
//   <li style="margin: 12px 0;"><a href="#conclusion" style="color: #0288d1; text-decoration: none; font-size: 18px; font-weight: 500;">🎯 Conclusion</a></li>
// </ul>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 id="section-1" style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">📌 Section 1: Introduction</h2>
//
// <p>Your content here. Use paragraphs to explain concepts clearly.</p>
//
// <p>You can include multiple paragraphs with proper spacing.</p>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 id="section-2" style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">🚀 Section 2: Cards Block Example</h2>
//
// <p>This section demonstrates how to use the cards block for features or key points.</p>
//
// <div class="cards block">
//   <div>
//     <div><strong>📊 Feature 1</strong></div>
//     <div>Description of first feature or key point with details.</div>
//   </div>
//   <div>
//     <div><strong>⚡ Feature 2</strong></div>
//     <div>Description of second feature or key point with details.</div>
//   </div>
//   <div>
//     <div><strong>🎨 Feature 3</strong></div>
//     <div>Description of third feature or key point with details.</div>
//   </div>
// </div>
//
// <script type="module">
//   const block = document.querySelector('.cards.block');
//   if (block) {
//     const module = await import('/blocks/cards/cards.js');
//     await module.default(block);
//   }
// </script>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 id="section-3" style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">💡 Section 3: Accordion Block Example</h2>
//
// <p>This section demonstrates how to use the accordion block for Q&A or collapsible content.</p>
//
// <div class="accordion block">
//   <div>
//     <div>Question or Topic 1</div>
//     <div>Answer or detailed explanation for the first topic goes here.</div>
//   </div>
//   <div>
//     <div>Question or Topic 2</div>
//     <div>Answer or detailed explanation for the second topic goes here.</div>
//   </div>
//   <div>
//     <div>Question or Topic 3</div>
//     <div>Answer or detailed explanation for the third topic goes here.</div>
//   </div>
// </div>
//
// <script type="module">
//   const block = document.querySelector('.accordion.block');
//   if (block) {
//     const module = await import('/blocks/accordion/accordion.js');
//     await module.default(block);
//   }
// </script>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">📝 Section 4: Tabs Block Example</h2>
//
// <p>This section demonstrates how to use the tabs block for organizing related information.</p>
//
// <div class="tabs block">
//   <div>
//     <div>Option 1</div>
//     <div>
//       <h3>Content for Option 1</h3>
//       <p>Details about the first option.</p>
//     </div>
//   </div>
//   <div>
//     <div>Option 2</div>
//     <div>
//       <h3>Content for Option 2</h3>
//       <p>Details about the second option.</p>
//     </div>
//   </div>
//   <div>
//     <div>Option 3</div>
//     <div>
//       <h3>Content for Option 3</h3>
//       <p>Details about the third option.</p>
//     </div>
//   </div>
// </div>
//
// <script type="module">
//   const block = document.querySelector('.tabs.block');
//   if (block) {
//     const module = await import('/blocks/tabs/tabs.js');
//     await module.default(block);
//   }
// </script>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 id="conclusion" style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">🎯 Conclusion</h2>
//
// <p>Summary of key points from the presentation.</p>
//
// <h3 style="color: #0d47a1; font-size: 26px; font-weight: 700; margin-bottom: 16px;">Key Takeaways</h3>
//
// <ul style="line-height: 1.8;">
//   <li>Main takeaway 1</li>
//   <li>Main takeaway 2</li>
//   <li>Main takeaway 3</li>
// </ul>
//
// <h3 style="color: #0d47a1; font-size: 26px; font-weight: 700; margin-top: 24px; margin-bottom: 16px;">Next Steps</h3>
//
// <p>What the audience should do next or where to find more information.</p>
//
// </div>
