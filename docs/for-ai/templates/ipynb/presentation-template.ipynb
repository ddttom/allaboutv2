// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); color: white; border-radius: 16px; padding: 48px; text-align: center; margin: 0 0; box-shadow: 0 8px 20px rgba(0,0,0,0.25); color: #212121;">
// <h1 style="font-size: 48px; font-weight: 800; margin: 0 0 16px 0; display: flex; align-items: center; justify-content: center; gap: 16px;">
// <span style="font-size: 56px;">🎯</span>
// <span>Your Presentation Title</span>
// </h1>
// <p style="font-size: 20px; margin: 16px 0; opacity: 0.95; font-weight: 300;">
// Your compelling subtitle or tagline goes here
// </p>
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 4px solid #0288d1; color: #212121;">
// <h3 style="color: #0d47a1; font-size: 26px; font-weight: 700; margin-bottom: 20px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 28px;">✨</span>
// What You'll Learn
// </h3>
//
// <p style="font-size: 16px; line-height: 1.8; margin-bottom: 16px;">Brief introduction to what this presentation covers.</p>
//
// <ul style="list-style: none; padding: 0; margin: 0;">
// <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 16px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 20px;">📌</span>
// <span>Key point 1</span>
// </li>
// <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 16px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 20px;">📌</span>
// <span>Key point 2</span>
// </li>
// <li style="padding: 12px 0; font-size: 16px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 20px;">📌</span>
// <span>Key point 3</span>
// </li>
// </ul>
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 32px;">📋</span>
// Table of Contents
// </h2>
//
// <nav aria-label="Presentation navigation">
//   <ul style="list-style: none; padding: 0; margin: 0;">
//     <li style="padding: 10px 0; border-bottom: 1px solid rgba(0,0,0,0.08);">
//       <a href="#section-1" style="color: #212121; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 8px 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
//         <span style="font-size: 20px;">📌</span>
//         Section 1: Introduction
//       </a>
//     </li>
//     <li style="padding: 10px 0; border-bottom: 1px solid rgba(0,0,0,0.08);">
//       <a href="#section-2" style="color: #212121; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 8px 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
//         <span style="font-size: 20px;">🚀</span>
//         Section 2: Main Content
//       </a>
//     </li>
//     <li style="padding: 10px 0; border-bottom: 1px solid rgba(0,0,0,0.08);">
//       <a href="#section-3" style="color: #212121; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 8px 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
//         <span style="font-size: 20px;">💡</span>
//         Section 3: Key Insights
//       </a>
//     </li>
//     <li style="padding: 10px 0;">
//       <a href="#conclusion" style="color: #212121; text-decoration: none; font-size: 18px; font-weight: 500; display: flex; align-items: center; gap: 8px; padding: 8px 12px; border-radius: 8px; transition: background 0.2s;" onmouseover="this.style.background='#f5f5f5'" onmouseout="this.style.background='transparent'">
//         <span style="font-size: 20px;">🎯</span>
//         Conclusion
//       </a>
//     </li>
//   </ul>
// </nav>
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">📌 Section 1: Introduction</h2>
//
// <p style="font-size: 16px; line-height: 1.8; margin-bottom: 16px;">Your content here. Use paragraphs to explain concepts clearly.</p>
//
// <p style="font-size: 16px; line-height: 1.8;">You can include multiple paragraphs with proper spacing.</p>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">🚀 Section 2: Cards Block Example</h2>
//
// <p style="font-size: 16px; line-height: 1.8; margin-bottom: 24px;">This section demonstrates how to use the cards block for features or key points.</p>
//
// <div class="cards block">
//   <div>
//     <div><strong>📊 Feature 1</strong></div>
//     <div>Description of first feature or key point with details.</div>
//   </div>
//   <div>
//     <div><strong>⚡ Feature 2</strong></div>
//     <div>Description of second feature or key point with details.</div>
//   </div>
//   <div>
//     <div><strong>🎨 Feature 3</strong></div>
//     <div>Description of third feature or key point with details.</div>
//   </div>
// </div>
//
// <script type="module">
//   const block = document.querySelector('.cards.block');
//   if (block) {
//     const module = await import('/blocks/cards/cards.js');
//     await module.default(block);
//   }
// </script>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">💡 Section 3: Accordion Block Example</h2>
//
// <p style="font-size: 16px; line-height: 1.8; margin-bottom: 24px;">This section demonstrates how to use the accordion block for Q&A or collapsible content.</p>
//
// <div class="accordion block">
//   <div>
//     <div>Question or Topic 1</div>
//     <div>Answer or detailed explanation for the first topic goes here.</div>
//   </div>
//   <div>
//     <div>Question or Topic 2</div>
//     <div>Answer or detailed explanation for the second topic goes here.</div>
//   </div>
//   <div>
//     <div>Question or Topic 3</div>
//     <div>Answer or detailed explanation for the third topic goes here.</div>
//   </div>
// </div>
//
// <script type="module">
//   const block = document.querySelector('.accordion.block');
//   if (block) {
//     const module = await import('/blocks/accordion/accordion.js');
//     await module.default(block);
//   }
// </script>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">📝 Section 4: Tabs Block Example</h2>
//
// <p style="font-size: 16px; line-height: 1.8; margin-bottom: 24px;">This section demonstrates how to use the tabs block for organizing related information.</p>
//
// <div class="tabs block">
//   <div>
//     <div>Option 1</div>
//     <div>
//       <h3>Content for Option 1</h3>
//       <p>Details about the first option.</p>
//     </div>
//   </div>
//   <div>
//     <div>Option 2</div>
//     <div>
//       <h3>Content for Option 2</h3>
//       <p>Details about the second option.</p>
//     </div>
//   </div>
//   <div>
//     <div>Option 3</div>
//     <div>
//       <h3>Content for Option 3</h3>
//       <p>Details about the third option.</p>
//     </div>
//   </div>
// </div>
//
// <script type="module">
//   const block = document.querySelector('.tabs.block');
//   if (block) {
//     const module = await import('/blocks/tabs/tabs.js');
//     await module.default(block);
//   }
// </script>
//
// </div>

// %% [markdown]
// <div style="background: linear-gradient(135deg, #e3f2fd 0%, #bbdefb 100%); border-radius: 12px; padding: 32px; margin: 0 0; border-left: 6px solid #0288d1; color: #212121;">
//
// <h2 style="color: #0d47a1; font-size: 28px; font-weight: 700; margin-bottom: 24px;">🎯 Conclusion</h2>
//
// <p style="font-size: 16px; line-height: 1.8; margin-bottom: 24px;">Summary of key points from the presentation.</p>
//
// <h3 style="color: #0d47a1; font-size: 26px; font-weight: 700; margin-bottom: 20px;">Key Takeaways</h3>
//
// <ul style="list-style: none; padding: 0; margin: 0 0 24px 0;">
// <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 16px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 20px;">✅</span>
// <span>Main takeaway 1</span>
// </li>
// <li style="padding: 12px 0; border-bottom: 1px solid rgba(0,0,0,0.08); font-size: 16px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 20px;">✅</span>
// <span>Main takeaway 2</span>
// </li>
// <li style="padding: 12px 0; font-size: 16px; display: flex; align-items: center; gap: 12px;">
// <span style="font-size: 20px;">✅</span>
// <span>Main takeaway 3</span>
// </li>
// </ul>
//
// <h3 style="color: #0d47a1; font-size: 26px; font-weight: 700; margin-bottom: 20px;">Next Steps</h3>
//
// <p style="font-size: 16px; line-height: 1.8;">What the audience should do next or where to find more information.</p>
//
// </div>
